# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 630

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={weather_api_key}&units={units}&q="

cloud = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind = []
country = []

citylist =[]


print("Beginning Data Retrieval")
print("-------------------------------")

sets = 1
record = 0

for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloud.append(response['clouds']['all'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        
        if record > 49:
            record = 1
            sets = sets + 1
            citylist.append(city)
            time.sleep(1)
        else:
            record = record + 1
            citylist.append(city)
        print(f"Processing Record {record} of Set {sets} | {city}")
        
        
    except Exception:
        print("City not found. Skipping...")

        
print("-------------------------------")
print("Data Retrieval Complete")
print("-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | nantucket
# Processing Record 2 of Set 1 | nara
# Processing Record 3 of Set 1 | longyearbyen
# Processing Record 4 of Set 1 | takoradi
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | saskylakh
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | japura
# Processing Record 9 of Set 1 | cape town
# Processing Record 10 of Set 1 | saint-philippe
# Processing Record 11 of Set 1 | kununurra
# Processing Record 12 of Set 1 | knin
# Processing Record 13 of Set 1 | hay river
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | chokurdakh
# Processing Record 16 of Set 1 | ribeira grande
# Processing Record 17 of Set 1 | kardailovo
# Processing Record 18 of Set 1 | atuona
# City not found. Skipping...
# Processing Record 19 of Set 1 | moanda
# Processing Record 20 of Set 1 | waseca
# Processing Record 21 of Set 1 | severo-kurilsk
# Processing Record 22 of Set 1 | santa clara
# Processing Record 23 of Set 1 | kapaa
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | abha
# Processing Record 26 of Set 1 | aswan
# Processing Record 27 of Set 1 | fairbanks
# Processing Record 28 of Set 1 | codrington
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | lebowakgomo
# City not found. Skipping...
# Processing Record 31 of Set 1 | nyurba
# Processing Record 32 of Set 1 | khatanga
# Processing Record 33 of Set 1 | kenai
# Processing Record 34 of Set 1 | ilulissat
# Processing Record 35 of Set 1 | ostrovnoy
# Processing Record 36 of Set 1 | teknaf
# Processing Record 37 of Set 1 | natal
# Processing Record 38 of Set 1 | waingapu
# City not found. Skipping...
# Processing Record 39 of Set 1 | worland
# City not found. Skipping...
# Processing Record 40 of Set 1 | north bend
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | lata
# Processing Record 43 of Set 1 | mys shmidta
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 44 of Set 1 | saldanha
# Processing Record 45 of Set 1 | zhezkazgan
# Processing Record 46 of Set 1 | arraial do cabo
# Processing Record 47 of Set 1 | hobart
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | albany
# Processing Record 50 of Set 1 | castro
# Processing Record 1 of Set 2 | jojoima
# City not found. Skipping...
# Processing Record 2 of Set 2 | chitral
# Processing Record 3 of Set 2 | manica
# Processing Record 4 of Set 2 | dikson
# Processing Record 5 of Set 2 | rudnichnyy
# Processing Record 6 of Set 2 | lengshuitan
# Processing Record 7 of Set 2 | fort madison
# Processing Record 8 of Set 2 | hamilton
# Processing Record 9 of Set 2 | inyonga
# City not found. Skipping...
# Processing Record 10 of Set 2 | busselton
# Processing Record 11 of Set 2 | vila franca do campo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record
# Processing Record 41 of Set 4 | puerto ayora
# Processing Record 42 of Set 4 | nelson bay
# Processing Record 43 of Set 4 | madang
# City not found. Skipping...
# Processing Record 44 of Set 4 | dvinskoy
# City not found. Skipping...
# Processing Record 45 of Set 4 | yarkovo
# Processing Record 46 of Set 4 | portland
# Processing Record 47 of Set 4 | tarko-sale
# Processing Record 48 of Set 4 | eureka
# Processing Record 49 of Set 4 | chuy
# Processing Record 50 of Set 4 | kavaratti
# Processing Record 1 of Set 5 | marawi
# Processing Record 2 of Set 5 | caluquembe
# City not found. Skipping...
# Processing Record 3 of Set 5 | marzuq
# Processing Record 4 of Set 5 | fort abbas
# Processing Record 5 of Set 5 | warmbad
# Processing Record 6 of Set 5 | kenora
# Processing Record 7 of Set 5 | salalah
# Processing Record 8 of Set 5 | fuzhou
# Processing Record 9 of Set 5 | hasaki
# Processing Record 10 of Set 5 | geraldton
# Processing Record 11 of Set 5 | ambon
# Processing Record 12 of Set 5 | funtua
# Processing Record 13 of Set 5 | ixtapa
# Processing Record 14 of Set 5 | hammerfest
# Processing Record 15 of Set 5 | shingu
# Processing Record 16 of Set 5 | parian dakula
# City not found. Skipping...
# Processing Record 17 of Set 5 | mae sot
# Processing Record 18 of Set 5 | mandalgovi
# Processing Record 19 of Set 5 | marshall
# Processing Record 20 of Set 5 | nanortalik
# Processing Record 21 of Set 5 | kropotkin
# City not found. Skipping...
# Processing Record 22 of Set 5 | tiksi
# City not found. Skipping...
# Processing Record 23 of Set 5 | san luis
# Processing Record 24 of Set 5 | iqaluit
# Processing Record 25 of Set 5 | hakkari
# Processing Record 26 of Set 5 | arlit
# Processing Record 27 of Set 5 | dartford
# Processing Record 28 of Set 5 | san quintin
# Processing Record 29 of Set 5 | matane
# Processing Record 30 of Set 5 | alvarado
# Processing Record 31 of Set 5 | north myrtle beach
# Processing Record 32 of Set 5 | simao dias
# Processing Record 33 of Set 5 | amazar
# Processing Record 34 of Set 5 | albuquerque
# Processing Record 35 of Set 5 | alice springs
# Processing Record 36 of Set 5 | isilkul
# Processing Record 37 of Set 5 | dunedin
# Processing Record 38 of Set 5 | cherskiy
# Processing Record 39 of Set 5 | korgen
# Processing Record 40 of Set 5 | placerville
# Processing Record 41 of Set 5 | kirkland lake
# City not found. Skipping...
# Processing Record 42 of Set 5 | keti bandar
# Processing Record 43 of Set 5 | tateyama
# Processing Record 44 of Set 5 | mount isa
# Processing Record 45 of Set 5 | panjab
# Processing Record 46 of Set 5 | alyangula
# Processing Record 47 of Set 5 | pandan
# Processing Record 48 of Set 5 | libreville
# Processing Record 49 of Set 5 | necochea
# Processing Record 50 of Set 5 | clyde river
# Processing Record 1 of Set 6 | paraiso
# Processing Record 2 of Set 6 | maridi
# Processing Record 3 of Set 6 | samarai
# Processing Record 4 of Set 6 | roma
# Processing Record 5 of Set 6 | sabha
# Processing Record 6 of Set 6 | norilsk
# Processing Record 7 of Set 6 | yinchuan
# Processing Record 8 of Set 6 | honningsvag
# Processing Record 9 of Set 6 | camacha
# Processing Record 10 of Set 6 | lorengau
# Processing Record 11 of Set 6 | ginir
# Processing Record 12 of Set 6 | sinnamary
# Processing Record 13 of Set 6 | yatou
# Processing Record 14 of Set 6 | tonj
# Processing Record 15 of Set 6 | gisborne
# Processing Record 16 of Set 6 | padang
# Processing Record 17 of Set 6 | springdale
# Processing Record 18 of Set 6 | aykhal
# Processing Record 19 of Set 6 | jiaocheng
# Processing Record 20 of Set 6 | qaqortoq
# Processing Record 21 of Set 6 | haines junction
# Processing Record 22 of Set 6 | half moon bay
# Processing Record 23 of Set 6 | coos bay
# Processing Record 24 of Set 6 | nome
# Processing Record 25 of Set 6 | zamosc
# Processing Record 26 of Set 6 | grand river south east
# Processing Record 27 of Set 6 | bredasdorp
# Processing Record 28 of Set 6 | esperance
# Processing Record 29 of Set 6 | bontang
# Processing Record 30 of Set 6 | sucre
# Processing Record 31 of Set 6 | castelnuovo rangone
# City not found. Skipping...
# Processing Record 32 of Set 6 | san policarpo
# Processing Record 33 of Set 6 | chumikan
# Processing Record 34 of Set 6 | myaundzha
# Processing Record 35 of Set 6 | mitu
# Processing Record 36 of Set 6 | sao filipe
# Processing Record 37 of Set 6 | sulangan
# Processing Record 38 of Set 6 | rocha
# Processing Record 39 of Set 6 | rafaela
# Processing Record 40 of Set 6 | bengkulu
# Processing Record 41 of Set 6 | grindavik
# Processing Record 42 of Set 6 | skjervoy
# City not found. Skipping...
# Processing Record 43 of Set 6 | maracas
# Processing Record 44 of Set 6 | langxiang
# Processing Record 45 of Set 6 | srednekolymsk
# Processing Record 46 of Set 6 | kirakira
# Processing Record 47 of Set 6 | raudeberg
# Processing Record 48 of Set 6 | vila
# Processing Record 49 of Set 6 | thinadhoo
# Processing Record 50 of Set 6 | rosario
# Processing Record 1 of Set 7 | waipawa
# Processing Record 2 of Set 7 | benito juarez
# Processing Record 3 of Set 7 | enid
# Processing Record 4 of Set 7 | faanui
# Processing Record 5 of Set 7 | luau
# Processing Record 6 of Set 7 | saint-joseph
# Processing Record 7 of Set 7 | chifeng
# Processing Record 8 of Set 7 | namibe
# Processing Record 9 of Set 7 | toowoomba
# City not found. Skipping...
# Processing Record 10 of Set 7 | nkpor
# Processing Record 11 of Set 7 | nishihara
# City not found. Skipping...
# Processing Record 12 of Set 7 | komsomolskiy
# Processing Record 13 of Set 7 | tasiilaq
# Processing Record 14 of Set 7 | kalianget
# Processing Record 15 of Set 7 | neuquen
# Processing Record 16 of Set 7 | barra do garcas
# Processing Record 17 of Set 7 | kiruna
# Processing Record 18 of Set 7 | prabumulih
# Processing Record 19 of Set 7 | rantepao
# City not found. Skipping...
# Processing Record 20 of Set 7 | binga
# Processing Record 21 of Set 7 | lompoc
# Processing Record 22 of Set 7 | lebu
# Processing Record 23 of Set 7 | cidreira
# City not found. Skipping...
# Processing Record 24 of Set 7 | alfenas
# Processing Record 25 of Set 7 | constitucion
# Processing Record 26 of Set 7 | belyy yar
# Processing Record 27 of Set 7 | berlevag
# Processing Record 28 of Set 7 | volksrust
# Processing Record 29 of Set 7 | erzin
# City not found. Skipping...
# City not found. Skipping...
# Processing Record
# Processing Record 7 of Set 10 | mandan
# City not found. Skipping...
# Processing Record 8 of Set 10 | linhares
# Processing Record 9 of Set 10 | acari
# Processing Record 10 of Set 10 | korla
# Processing Record 11 of Set 10 | boyolangu
# Processing Record 12 of Set 10 | matadi
# Processing Record 13 of Set 10 | pocatello
# Processing Record 14 of Set 10 | kihei
# Processing Record 15 of Set 10 | port hardy
# Processing Record 16 of Set 10 | honiara
# Processing Record 17 of Set 10 | atoyac
# Processing Record 18 of Set 10 | sao miguel do tapuio
# Processing Record 19 of Set 10 | namatanai
# Processing Record 20 of Set 10 | dukat
# Processing Record 21 of Set 10 | eirunepe
# Processing Record 22 of Set 10 | meulaboh
# City not found. Skipping...
# Processing Record 23 of Set 10 | aksay
# Processing Record 24 of Set 10 | rawson
# Processing Record 25 of Set 10 | kashi
# Processing Record 26 of Set 10 | liverpool
# Processing Record 27 of Set 10 | myrtle beach
# Processing Record 28 of Set 10 | mangrol
# Processing Record 29 of Set 10 | whitehorse
# Processing Record 30 of Set 10 | dongsheng
# Processing Record 31 of Set 10 | singaraja
# Processing Record 32 of Set 10 | dickinson
# City not found. Skipping...
# Processing Record 33 of Set 10 | praia
# Processing Record 34 of Set 10 | luganville
# Processing Record 35 of Set 10 | carballo
# Processing Record 36 of Set 10 | filingue
# Processing Record 37 of Set 10 | sur
# Processing Record 38 of Set 10 | tyukalinsk
# Processing Record 39 of Set 10 | moyale
# Processing Record 40 of Set 10 | zhigalovo
# Processing Record 41 of Set 10 | kudahuvadhoo
# Processing Record 42 of Set 10 | lekoni
# City not found. Skipping...
# Processing Record 43 of Set 10 | praia da vitoria
# Processing Record 44 of Set 10 | lasa
# Processing Record 45 of Set 10 | johnson city
# Processing Record 46 of Set 10 | alibag
# Processing Record 47 of Set 10 | graham
# Processing Record 48 of Set 10 | nuevitas
# Processing Record 49 of Set 10 | angoram
# City not found. Skipping...
# Processing Record 50 of Set 10 | shenzhen
# Processing Record 1 of Set 11 | scarborough
# City not found. Skipping...
# Processing Record 2 of Set 11 | barranca
# Processing Record 3 of Set 11 | grants pass
# Processing Record 4 of Set 11 | vostok
# Processing Record 5 of Set 11 | paulo afonso
# Processing Record 6 of Set 11 | alexandria
# Processing Record 7 of Set 11 | buala
# Processing Record 8 of Set 11 | royan
# City not found. Skipping...
# Processing Record 9 of Set 11 | bubaque
# Processing Record 10 of Set 11 | lazaro cardenas
# Processing Record 11 of Set 11 | fort dodge
# Processing Record 12 of Set 11 | jaen
# Processing Record 13 of Set 11 | port-gentil
# Processing Record 14 of Set 11 | koindu
# Processing Record 15 of Set 11 | ligayan
# Processing Record 16 of Set 11 | tadine
# Processing Record 17 of Set 11 | ventersburg
# Processing Record 18 of Set 11 | olutanga
# Processing Record 19 of Set 11 | sangat
# Processing Record 20 of Set 11 | christchurch
# Processing Record 21 of Set 11 | pontian kecil
# Processing Record 22 of Set 11 | zavodoukovsk
# City not found. Skipping...
# Processing Record 23 of Set 11 | torring
# City not found. Skipping...
# Processing Record 24 of Set 11 | poum
# Processing Record 25 of Set 11 | smolenka
# Processing Record 26 of Set 11 | ouallam
# Processing Record 27 of Set 11 | ocampo
# Processing Record 28 of Set 11 | kibaya
# Processing Record 29 of Set 11 | duldurga
# City not found. Skipping...
# Processing Record 30 of Set 11 | malaba
# City not found. Skipping...
# Processing Record 31 of Set 11 | adiake
# Processing Record 32 of Set 11 | yumen
# Processing Record 33 of Set 11 | vao
# Processing Record 34 of Set 11 | ngudu
# Processing Record 35 of Set 11 | boditi
# Processing Record 36 of Set 11 | bridlington
# Processing Record 37 of Set 11 | mpulungu
# Processing Record 38 of Set 11 | camacari
# Processing Record 39 of Set 11 | makakilo city
# Processing Record 40 of Set 11 | beaverlodge
# Processing Record 41 of Set 11 | aviles
# Processing Record 42 of Set 11 | suntar
# City not found. Skipping...
# Processing Record 43 of Set 11 | havre-saint-pierre
# Processing Record 44 of Set 11 | turukhansk
# Processing Record 45 of Set 11 | tiruchchendur
# Processing Record 46 of Set 11 | karlskrona
# Processing Record 47 of Set 11 | sambava
# Processing Record 48 of Set 11 | muravlenko
# Processing Record 49 of Set 11 | ardatov
# Processing Record 50 of Set 11 | dhidhdhoo
# Processing Record 1 of Set 12 | malanje
# Processing Record 2 of Set 12 | penzance
# Processing Record 3 of Set 12 | urubicha
# Processing Record 4 of Set 12 | verkh-usugli
# Processing Record 5 of Set 12 | domoni
# Processing Record 6 of Set 12 | mayskiy
# City not found. Skipping...
# Processing Record 7 of Set 12 | college
# Processing Record 8 of Set 12 | seoul
# Processing Record 9 of Set 12 | naron
# Processing Record 10 of Set 12 | kempsey
# Processing Record 11 of Set 12 | williams lake
# Processing Record 12 of Set 12 | sorland
# Processing Record 13 of Set 12 | schoneiche
# Processing Record 14 of Set 12 | tazovskiy
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df = pd.DataFrame({"City":citylist,"Cloudiness":cloud,"Country":country,
    "Date":date,"Humidity":humidity,"Lat":lat,"Lng":lng,"Max Temp":max_temp,"Wind Speed":wind})

city_df.to_csv("../output_data/cities_file")
    
city_df.count()
# Out:
# City          564
# Cloudiness    564
# Country       564
# Date          564
# Humidity      564
# Lat           564
# Lng           564
# Max Temp      564
# Wind Speed    564
# dtype: int64

# %%
city_df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     nantucket          40      US  1580224393        52  41.28  -70.10
# 1          nara          90      JP  1580224393        93  34.69  135.80
# 2  longyearbyen          76      SJ  1580224387        64  78.22   15.64
# 3      takoradi          98      GH  1580224393        57   4.88   -1.76
# 4       rikitea         100      PF  1580224393        80 -23.12 -134.97
#
#    Max Temp  Wind Speed
# 0     42.80       14.99
# 1     53.01       18.34
# 2      1.40        8.05
# 3     87.91       10.49
# 4     78.98        9.84

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(city_df["Lat"],city_df["Max Temp"],marker="o", facecolors="skyblue", edgecolors="black", alpha=0.75)

plt.title("City Latitude vs. Max Temperature (1/26/2020)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.savefig("../output_data/Lat_vs_Tem.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_df["Lat"],city_df["Humidity"],marker="o", facecolors="skyblue", edgecolors="black", alpha=0.75)

plt.title("City Latitude vs. Humidity (1/26/2020) ")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(15,105)
plt.savefig("../output_data/Lat_vs_Hum.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_df["Lat"],city_df["Cloudiness"],marker="o", facecolors="skyblue", edgecolors="black", alpha=0.75)

plt.title("City Latitude vs. Cloudiness (1/26/2020)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("../output_data/Lat_vs_Cloud.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_df["Lat"],city_df["Wind Speed"],marker="o", facecolors="skyblue", edgecolors="black", alpha=0.75)

plt.title("City Latitude vs. Wind Speed (1/26/2020)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(-2,34)
plt.savefig("../output_data/Lat_vs_Wind.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
Northern_Filter = city_df.loc[(city_df["Lat"]>=0),:]

Southern_Filter = city_df.loc[(city_df["Lat"]<0),:]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = Northern_Filter["Lat"]
y_values = Northern_Filter["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Northern Hemisphere - Max Temp vs. Latitude ")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()
print(f"The r-squared is: {rvalue}")
plt.savefig("../output_data/North_Hem_fig1.png")
# Out:
# The r-squared is: -0.8676689846973947

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = Southern_Filter["Lat"]
y_values = Southern_Filter["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Northern Hemisphere - Max Temp vs. Latitude ")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.show()
plt.savefig("../output_data/South_Hem_fig1.png")
print(f"The r-squared is: {rvalue}")
# Out:
# The r-squared is: 0.5004433860103507

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = Northern_Filter["Lat"]
y_values = Northern_Filter["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()
plt.savefig("../output_data/North_Hem_fig2.png")
print(f"The r-squared is: {rvalue}")
# Out:
# The r-squared is: 0.4425068347946389

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = Southern_Filter["Lat"]
y_values = Southern_Filter["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.show()
plt.savefig("../output_data/South_Hem_fig2.png")
print(f"The r-squared is: {rvalue}")
# Out:
# The r-squared is: 0.17631233980941402

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = Northern_Filter["Lat"]
y_values = Northern_Filter["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()
plt.savefig("../output_data/North_Hem_fig3.png")
print(f"The r-squared is: {rvalue}")
# Out:
# The r-squared is: 0.26070996938518515

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = Southern_Filter["Lat"]
y_values = Southern_Filter["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.show()
plt.savefig("../output_data/South_Hem_fig3.png")
print(f"The r-squared is: {rvalue}")
# Out:
# The r-squared is: 0.2740969612986881

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = Northern_Filter["Lat"]
y_values = Northern_Filter["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()
plt.savefig("../output_data/North_Hem_fig4.png")
print(f"The r-squared is: {rvalue}")
# Out:
# The r-squared is: 0.11931925862863663

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = Southern_Filter["Lat"]
y_values = Southern_Filter["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.show()
plt.savefig("../output_data/South_Hem_fig4.png")
print(f"The r-squared is: {rvalue}")
# Out:
# The r-squared is: -0.1573747339979317
